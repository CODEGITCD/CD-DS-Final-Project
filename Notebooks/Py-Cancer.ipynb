# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI

# %%
llm = OpenAI(api_token="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")
pandas_ai = PandasAI

# %%
df = pd.read_csv("../Data/lifestyle.csv")

# %%
df2 = pd.read_csv(r"C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\StatePrevalence2.csv")

# %%
df.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise
# 0                                30.67
# 1                                19.63
# 2                                22.13
# 3                                30.97
# 4                                20.98

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.to_csv("../Data/new_lifestyle.csv")

# %%
df2.head()
# Out:
#                    Area          Cancer Type                 Duration
# 0               Wyoming  All Types of Cancer  5-year Limited Duration  \
# 1  District of Columbia  All Types of Cancer  5-year Limited Duration
# 2                Alaska  All Types of Cancer  5-year Limited Duration
# 3               Vermont  All Types of Cancer  5-year Limited Duration
# 4          North Dakota  All Types of Cancer  5-year Limited Duration
#
#                Sex                       Race Prevalence Count
# 0  Male and Female  All Races and Ethnicities             9656  \
# 1  Male and Female  All Races and Ethnicities             9740
# 2  Male and Female  All Races and Ethnicities             9984
# 3  Male and Female  All Races and Ethnicities            13064
# 4  Male and Female  All Races and Ethnicities            13123
#
#   Prevalence Percentage
# 0            1.66601965
# 1            1.37921269
# 2            1.35815762
# 3            2.09216814
# 4            1.72242034

# %%
df2.Area.value_counts()
# Out:
# Area
# Wyoming                 1
# Texas                   1
# Wisconsin               1
# Indiana                 1
# Tennessee               1
# Washington              1
# Georgia                 1
# New Jersey              1
# North Carolina          1
# Ohio                    1
# Illinois                1
# Pennsylvania            1
# New York                1
# Maryland                1
# Florida                 1
# California              1
# Hawaii                  1
# South Dakota            1
# Iowa                    1
# Massachusetts           1
# Connecticut             1
# Nevada                  1
# Virginia                1
# New Mexico              1
# Missouri                1
# Arizona                 1
# District of Columbia    1
# West Virginia           1
# Alaska                  1
# Vermont                 1
# North Dakota            1
# Delaware                1
# Montana                 1
# Rhode Island            1
# Idaho                   1
# New Hampshire           1
# Maine                   1
# Nebraska                1
# Utah                    1
# Minnesota               1
# Mississippi             1
# Kansas                  1
# Arkansas                1
# Oklahoma                1
# Oregon                  1
# Colorado                1
# Louisiana               1
# Alabama                 1
# Kentucky                1
# South Carolina          1
# Michigan                1
# Name: count, dtype: int64

# %%
df2.Area.unique()
# Out:
# array(['Wyoming', 'District of Columbia', 'Alaska', 'Vermont',
#        'North Dakota', 'Delaware', 'Montana', 'Rhode Island', 'Idaho',
#        'New Hampshire', 'Maine', 'Nebraska', 'West Virginia', 'Utah',
#        'Mississippi', 'Kansas', 'Arkansas', 'Oklahoma', 'Oregon',
#        'Colorado', 'Louisiana', 'Alabama', 'Kentucky', 'South Carolina',
#        'Minnesota', 'Arizona', 'Maryland', 'Missouri', 'Wisconsin',
#        'Indiana', 'Tennessee', 'Washington', 'Georgia', 'New Jersey',
#        'North Carolina', 'Ohio', 'Illinois', 'Pennsylvania', 'Texas',
#        'New York', 'Florida', 'California', 'Hawaii', 'South Dakota',
#        'Iowa', 'Massachusetts', 'Connecticut', 'Nevada', 'Virginia',
#        'New Mexico', 'Michigan'], dtype=object)

# %%
df.State.value_counts()
# Out:
# State
# Alabama                 1
# Pennsylvania            1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Rhode Island            1
# Montana                 1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Nebraska                1
# Missouri                1
# Alaska                  1
# Idaho                   1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# District of Columbia    1
# Florida                 1
# Georgia                 1
# Hawaii                  1
# Illinois                1
# Mississippi             1
# Indiana                 1
# Iowa                    1
# Kansas                  1
# Kentucky                1
# Louisiana               1
# Maine                   1
# Maryland                1
# Massachusetts           1
# Michigan                1
# Minnesota               1
# Wyoming                 1
# Name: count, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Area                   51 non-null     object
#  1   Cancer Type            51 non-null     object
#  2   Duration               51 non-null     object
#  3   Sex                    51 non-null     object
#  4   Race                   51 non-null     object
#  5   Prevalence Count       51 non-null     object
#  6   Prevalence Percentage  51 non-null     object
# dtypes: object(7)
# memory usage: 2.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                51 non-null     object
#  1   Percentage Affected by Smoking       51 non-null     float64
#  2   Percentage Affected by Obesity       51 non-null     float64
#  3   Percentage Affected by No Excercise  51 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %%
merged_df = pd.merge(df, df2, left_on='State', right_on='Area')

# %%
merged_df.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise        Area          Cancer Type
# 0                                30.67     Alabama  All Types of Cancer  \
# 1                                19.63      Alaska  All Types of Cancer
# 2                                22.13     Arizona  All Types of Cancer
# 3                                30.97    Arkansas  All Types of Cancer
# 4                                20.98  California  All Types of Cancer
#
#                   Duration              Sex                       Race
# 0  5-year Limited Duration  Male and Female  All Races and Ethnicities  \
# 1  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 2  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 3  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 4  5-year Limited Duration  Male and Female  All Races and Ethnicities
#
#   Prevalence Count Prevalence Percentage
# 0            85304            1.74097026
# 1             9984            1.35815762
# 2           105926             1.4654881
# 3            54790            1.81629949
# 4           582663            1.47743255

# %%
merged_df.shape
# Out:
# (51, 11)

# %%
df.shape
# Out:
# (51, 4)

# %%
df2.shape
# Out:
# (51, 7)

# %%
merged_df.to_csv(r'C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\merged_df.csv', index=False)

# %%
df_survivability = pd.read_csv(r"C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\SurvivalbyState.csv")

# %%
df_survivability.head()
# Out:
#             Area          Cancer Type              Sex
# 0           Utah  All Types of Cancer  Male and Female  \
# 1       Colorado  All Types of Cancer  Male and Female
# 2      Minnesota  All Types of Cancer  Male and Female
# 3  New Hampshire  All Types of Cancer  Male and Female
# 4     Washington  All Types of Cancer  Male and Female
#
#                         Race 5-year relative survival
# 0  All Races and Ethnicities                     73.2
# 1  All Races and Ethnicities                     70.4
# 2  All Races and Ethnicities                     69.9
# 3  All Races and Ethnicities                     69.8
# 4  All Races and Ethnicities                     69.4

# %%
merged_df2 = pd.merge(merged_df,df_survivability, left_on='State', right_on='Area')

# %%
merged_df2.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise      Area_x        Cancer Type_x
# 0                                30.67     Alabama  All Types of Cancer  \
# 1                                19.63      Alaska  All Types of Cancer
# 2                                22.13     Arizona  All Types of Cancer
# 3                                30.97    Arkansas  All Types of Cancer
# 4                                20.98  California  All Types of Cancer
#
#                   Duration            Sex_x                     Race_x
# 0  5-year Limited Duration  Male and Female  All Races and Ethnicities  \
# 1  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 2  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 3  5-year Limited Duration  Male and Female  All Races and Ethnicities
# 4  5-year Limited Duration  Male and Female  All Races and Ethnicities
#
#   Prevalence Count Prevalence Percentage      Area_y        Cancer Type_y
# 0            85304            1.74097026     Alabama  All Types of Cancer  \
# 1             9984            1.35815762      Alaska  All Types of Cancer
# 2           105926             1.4654881     Arizona  All Types of Cancer
# 3            54790            1.81629949    Arkansas  All Types of Cancer
# 4           582663            1.47743255  California  All Types of Cancer
#
#              Sex_y                     Race_y 5-year relative survival
# 0  Male and Female  All Races and Ethnicities                     63.0
# 1  Male and Female  All Races and Ethnicities                     66.1
# 2  Male and Female  All Races and Ethnicities                     64.0
# 3  Male and Female  All Races and Ethnicities                     63.2
# 4  Male and Female  All Races and Ethnicities                     67.9

# %% [markdown]
# #######  Removed unnessasary columns witrh code below ######

# %%
cols_to_remove = ['Area_x','Area_y', 'Cancer Type_y','Cancer Type_x', 'Sex_x','Sex_y','Race_x','Race_y']
merged_df2.drop(cols_to_remove, axis=1, inplace=True)

# %%
merged_df2.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise                 Duration
# 0                                30.67  5-year Limited Duration  \
# 1                                19.63  5-year Limited Duration
# 2                                22.13  5-year Limited Duration
# 3                                30.97  5-year Limited Duration
# 4                                20.98  5-year Limited Duration
#
#   Prevalence Count Prevalence Percentage 5-year relative survival
# 0            85304            1.74097026                     63.0
# 1             9984            1.35815762                     66.1
# 2           105926             1.4654881                     64.0
# 3            54790            1.81629949                     63.2
# 4           582663            1.47743255                     67.9

# %% [markdown]
#  ##### editing names to make easier for analysis ####

# %%
#with the dataset "merged_df2" rename "Prevalence Percentage" to "Pervailence of Cancer by state percentage"

# %%
merged_df2 = merged_df2.rename(columns={'Prevalence Percentage':'Prevalence of Cancer by state %'})

# %%
merged_df2.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise                 Duration
# 0                                30.67  5-year Limited Duration  \
# 1                                19.63  5-year Limited Duration
# 2                                22.13  5-year Limited Duration
# 3                                30.97  5-year Limited Duration
# 4                                20.98  5-year Limited Duration
#
#   Prevalence Count Prevalence of Cancer by state % 5-year relative survival
# 0            85304                      1.74097026                     63.0
# 1             9984                      1.35815762                     66.1
# 2           105926                       1.4654881                     64.0
# 3            54790                      1.81629949                     63.2
# 4           582663                      1.47743255                     67.9

# %%
df_added_data = pd.read_csv(r"C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\reported weekly aerobic activity.csv")

# %%
df_added_data = df_added_data.rename(columns={'Age-adjusted Prevalence': 'Weekly arobic activity standard meet by state %'})

# %%
df_added_data.head()
# Out:
#          State                       Race              Sex
# 0   New Jersey  All Races and Ethnicities  Male and Female  \
# 1     Kentucky  All Races and Ethnicities  Male and Female
# 2  Puerto Rico  All Races and Ethnicities  Male and Female
# 3     Oklahoma  All Races and Ethnicities  Male and Female
# 4  Mississippi  All Races and Ethnicities  Male and Female
#
#   Weekly arobic activity standard meet by state % Total Respondents
# 0                                 Data Suppressed   Data Suppressed
# 1                                            23.7              7974
# 2                                            29.1              6032
# 3                                            31.3              6335
# 4                                            35.5              5126

# %%
df_added_data2= pd.read_csv("../Data/Vegetable Consumption - less than once per day.csv")

# %%
df_added_data2 = df_added_data2.rename(columns={'Age-adjusted Prevalence': 'Vegetable Consumption % - less than once per day'})

# %%
df_added_data2.head()
# Out:
#                   State                       Race              Sex
# 0               Florida  All Races and Ethnicities  Male and Female  \
# 1                 Maine  All Races and Ethnicities  Male and Female
# 2               Vermont  All Races and Ethnicities  Male and Female
# 3  District of Columbia  All Races and Ethnicities  Male and Female
# 4         New Hampshire  All Races and Ethnicities  Male and Female
#
#   Vegetable Consumption % - less than once per day Total Respondents
# 0                                  Data Suppressed   Data Suppressed
# 1                                             11.8             11808
# 2                                             11.8              6580
# 3                                             12.8              3198
# 4                                               13              6536

# %%
df_added_data3 = pd.read_csv("../Data/Fruit Consumption - less than once per day.csv")

# %%
df_added_data3 = df_added_data3.rename(columns={'Age-adjusted Prevalence': 'Fruit Consumption % - less than once per day'})

# %%
df_added_data3.head()
# Out:
#                   State                       Race              Sex
# 0               Florida  All Races and Ethnicities  Male and Female  \
# 1  District of Columbia  All Races and Ethnicities  Male and Female
# 2            New Jersey  All Races and Ethnicities  Male and Female
# 3           Connecticut  All Races and Ethnicities  Male and Female
# 4              New York  All Races and Ethnicities  Male and Female
#
#   Fruit Consumption % - less than once per day Total Respondents
# 0                              Data Suppressed   Data Suppressed
# 1                                           26              3198
# 2                                         29.5              7965
# 3                                         30.1              8341
# 4                                         30.1             39095

# %%
df_added_data4 = pd.read_csv("../Data/Binge Drinking.csv")

# %%
df_added_data4 = df_added_data4.rename(columns={'Age-adjusted Prevalence': 'Binge Drinking % per state'})

# %%
df_added_data4.head()
# Out:
#       State                       Race              Sex
# 0   Florida  All Races and Ethnicities  Male and Female  \
# 1      Utah  All Races and Ethnicities  Male and Female
# 2  Oklahoma  All Races and Ethnicities  Male and Female
# 3  Maryland  All Races and Ethnicities  Male and Female
# 4  Delaware  All Races and Ethnicities  Male and Female
#
#   Binge Drinking % per state Total Respondents
# 0            Data Suppressed   Data Suppressed
# 1                       10.9             10621
# 2                       11.2              5451
# 3                       12.4             15627
# 4                       12.5              3640

# %%
combined_added_df = pd.merge(df_added_data, df_added_data2, left_on='State', right_on='State')

# %%
cols_to_remove = ['Total Respondents_x','Total Respondents_y','Sex_x','Sex_y','Race_x','Race_y']
combined_added_df.drop(cols_to_remove, axis=1, inplace=True)

# %%
combined_added_df.head()
# Out:
#          State Weekly arobic activity standard meet by state %
# 0   New Jersey                                 Data Suppressed  \
# 1     Kentucky                                            23.7
# 2  Puerto Rico                                            29.1
# 3     Oklahoma                                            31.3
# 4  Mississippi                                            35.5
#
#   Vegetable Consumption % - less than once per day
# 0                                             17.4
# 1                                             17.2
# 2                                             43.3
# 3                                             15.9
# 4                                             20.1

# %%
combined_added_df2 = pd.merge(df_added_data3, df_added_data4, left_on='State', right_on='State')

# %%
cols_to_remove = ['Total Respondents_x','Total Respondents_y','Sex_x','Sex_y','Race_x','Race_y']
combined_added_df2.drop(cols_to_remove, axis=1, inplace=True)

# %%
combined_added_df2.head()
# Out:
#                   State Fruit Consumption % - less than once per day
# 0               Florida                              Data Suppressed  \
# 1  District of Columbia                                           26
# 2            New Jersey                                         29.5
# 3           Connecticut                                         30.1
# 4              New York                                         30.1
#
#   Binge Drinking % per state
# 0            Data Suppressed
# 1                       19.3
# 2                       13.9
# 3                       13.3
# 4                       13.9

# %%
combined_df_with_NULL_VALUE = pd.merge(combined_added_df,combined_added_df2, left_on='State', right_on='State')

# %%
combined_df_with_NULL_VALUE.head()
# Out:
#          State Weekly arobic activity standard meet by state %
# 0   New Jersey                                 Data Suppressed  \
# 1     Kentucky                                            23.7
# 2  Puerto Rico                                            29.1
# 3     Oklahoma                                            31.3
# 4  Mississippi                                            35.5
#
#   Vegetable Consumption % - less than once per day
# 0                                             17.4  \
# 1                                             17.2
# 2                                             43.3
# 3                                             15.9
# 4                                             20.1
#
#   Fruit Consumption % - less than once per day Binge Drinking % per state
# 0                                         29.5                       13.9
# 1                                         40.9                       12.6
# 2                                         49.3                       13.2
# 3                                         40.3                       11.2
# 4                                         42.6                       12.7

# %%
completed_added_df1_2 = df.dropna()

# %%
completed_added_df1_2.head()
# Out:
#         State  Percentage Affected by Smoking  Percentage Affected by Obesity
# 0     Alabama                           43.94                           36.69  \
# 1      Alaska                           43.22                           30.10
# 2     Arizona                           40.35                           30.60
# 3    Arkansas                           47.06                           37.59
# 4  California                           33.45                           26.38
#
#    Percentage Affected by No Excercise
# 0                                30.67
# 1                                19.63
# 2                                22.13
# 3                                30.97
# 4                                20.98

# %%
Lifestyle_Factors_df = pd.merge(combined_df_with_NULL_VALUE,merged_df2, left_on='State', right_on='State')

# %%
Lifestyle_Factors_df
# Out:
#                    State Weekly arobic activity standard meet by state %
# 0             New Jersey                                 Data Suppressed  \
# 1               Kentucky                                            23.7
# 2               Oklahoma                                            31.3
# 3            Mississippi                                            35.5
# 4              Louisiana                                            38.6
# 5                Alabama                                            39.5
# 6              Tennessee                                            39.9
# 7               Arkansas                                            40.5
# 8                Indiana                                            40.5
# 9               Missouri                                            40.6
# 10        South Carolina                                            40.6
# 11              New York                                            41.1
# 12               Georgia                                            41.4
# 13          South Dakota                                            41.8
# 14                 Texas                                            41.8
# 15          Rhode Island                                            42.4
# 16                Kansas                                            42.6
# 17                  Ohio                                            42.6
# 18              Virginia                                            43.1
# 19                  Iowa                                            43.2
# 20          North Dakota                                            43.5
# 21              Nebraska                                            43.7
# 22                Nevada                                            44.2
# 23               Florida                                            44.8
# 24              Delaware                                            44.9
# 25              Maryland                                              45
# 26        North Carolina                                            45.1
# 27         West Virginia                                            45.1
# 28              Illinois                                            45.2
# 29                 Maine                                            45.3
# 30           Connecticut                                            45.5
# 31          Pennsylvania                                            45.5
# 32  District of Columbia                                            45.9
# 33         Massachusetts                                            46.1
# 34               Arizona                                            46.2
# 35              Michigan                                            46.4
# 36            California                                            47.6
# 37         New Hampshire                                            47.8
# 38             Wisconsin                                              48
# 39               Wyoming                                            49.2
# 40                 Idaho                                            49.4
# 41                Hawaii                                            49.7
# 42            Washington                                            49.7
# 43            New Mexico                                            49.8
# 44                Oregon                                            49.8
# 45                Alaska                                            50.4
# 46                  Utah                                            50.5
# 47             Minnesota                                            51.2
# 48              Colorado                                            51.3
# 49               Vermont                                            53.6
# 50               Montana                                            57.7
#
#    Vegetable Consumption % - less than once per day
# 0                                              17.4  \
# 1                                              17.2
# 2                                              15.9
# 3                                              20.1
# 4                                              20.2
# 5                                              17.9
# 6                                              16.2
# 7                                              16.8
# 8                                              17.2
# 9                                              17.4
# 10                                             16.2
# 11                                             16.8
# 12                                             15.3
# 13                                             17.3
# 14                                             20.1
# 15                                             16.4
# 16                                               17
# 17                                             16.2
# 18                                             15.2
# 19                                             20.4
# 20                                             20.1
# 21                                             18.7
# 22                                             21.7
# 23                                  Data Suppressed
# 24                                             17.4
# 25                                               16
# 26                                             16.5
# 27                                             16.5
# 28                                             14.2
# 29                                             11.8
# 30                                             16.7
# 31                                             16.7
# 32                                             12.8
# 33                                             15.2
# 34                                               19
# 35                                             15.6
# 36                                             19.7
# 37                                               13
# 38                                             18.1
# 39                                             16.9
# 40                                             14.2
# 41                                             19.8
# 42                                             16.7
# 43                                             19.6
# 44                                             14.5
# 45                                             15.7
# 46                                             17.4
# 47                                             17.7
# 48                                               16
# 49                                             11.8
# 50                                             15.1
#
#    Fruit Consumption % - less than once per day Binge Drinking % per state
# 0                                          29.5                       13.9  \
# 1                                          40.9                       12.6
# 2                                          40.3                       11.2
# 3                                          42.6                       12.7
# 4                                          40.7                       16.3
# 5                                          41.3                       12.7
# 6                                          39.6                       14.3
# 7                                          38.8                       12.6
# 8                                          36.1                       15.1
# 9                                          40.1                       17.3
# 10                                         34.2                       14.2
# 11                                         30.1                       13.9
# 12                                         33.4                       13.3
# 13                                         40.6                       20.3
# 14                                         34.9                         15
# 15                                         30.1                       17.2
# 16                                         39.2                       17.8
# 17                                         37.3                       16.9
# 18                                         34.3                       15.1
# 19                                         38.3                       20.7
# 20                                         40.2                       20.3
# 21                                         39.3                       19.6
# 22                                         38.2                       12.7
# 23                              Data Suppressed            Data Suppressed
# 24                                         34.1                       12.5
# 25                                         31.2                       12.4
# 26                                         37.4                       15.4
# 27                                           42                       12.9
# 28                                         35.1                         15
# 29                                         32.5                       16.9
# 30                                         30.1                       13.3
# 31                                           35                       15.4
# 32                                           26                       19.3
# 33                                         33.8                       16.4
# 34                                         37.8                         16
# 35                                           33                         16
# 36                                         32.5                       14.4
# 37                                         31.4                       14.4
# 38                                           36                       22.2
# 39                                         39.1                         16
# 40                                         37.7                       14.2
# 41                                         39.5                       17.1
# 42                                         32.2                       14.7
# 43                                         38.1                       13.9
# 44                                         34.3                       15.8
# 45                                           37                       16.4
# 46                                         33.5                       10.9
# 47                                         32.2                       17.7
# 48                                         33.3                         18
# 49                                         30.5                       17.9
# 50                                         37.5                       21.7
#
#     Percentage Affected by Smoking  Percentage Affected by Obesity
# 0                            37.06                           26.28  \
# 1                            50.40                           37.58
# 2                            44.52                           35.63
# 3                            42.85                           39.88
# 4                            43.17                           37.08
# 5                            43.94                           36.69
# 6                            45.49                           34.91
# 7                            47.06                           37.59
# 8                            45.03                           34.79
# 9                            44.08                           35.80
# 10                           43.59                           34.95
# 11                           36.31                           28.04
# 12                           37.64                           33.01
# 13                           44.17                           30.87
# 14                           36.08                           35.51
# 15                           42.16                           28.41
# 16                           41.85                           35.25
# 17                           45.77                           34.64
# 18                           37.78                           31.23
# 19                           41.03                           36.28
# 20                           42.73                           36.62
# 21                           39.73                           34.80
# 22                           41.46                           30.50
# 23                           41.89                           31.17
# 24                           42.27                           34.37
# 25                           36.02                           31.61
# 26                           43.03                           33.79
# 27                           49.54                           39.98
# 28                           38.29                           32.25
# 29                           49.73                           30.78
# 30                           39.47                           28.17
# 31                           42.86                           31.77
# 32                           34.72                           25.15
# 33                           38.50                           26.40
# 34                           40.35                           30.60
# 35                           45.38                           33.89
# 36                           33.45                           26.38
# 37                           45.18                           30.09
# 38                           42.72                           32.93
# 39                           45.14                           29.71
# 40                           38.19                           29.60
# 41                           39.40                           25.18
# 42                           38.11                           29.57
# 43                           40.71                           32.93
# 44                           43.12                           30.59
# 45                           43.22                           30.10
# 46                           24.95                           28.41
# 47                           41.05                           30.58
# 48                           40.43                           23.45
# 49                           44.05                           28.22
# 50                           44.48                           27.78
#
#     Percentage Affected by No Excercise                 Duration
# 0                                 28.53  5-year Limited Duration  \
# 1                                 32.44  5-year Limited Duration
# 2                                 27.20  5-year Limited Duration
# 3                                 32.01  5-year Limited Duration
# 4                                 30.83  5-year Limited Duration
# 5                                 30.67  5-year Limited Duration
# 6                                 30.88  5-year Limited Duration
# 7                                 30.97  5-year Limited Duration
# 8                                 27.35  5-year Limited Duration
# 9                                 26.11  5-year Limited Duration
# 10                                26.73  5-year Limited Duration
# 11                                23.84  5-year Limited Duration
# 12                                26.24  5-year Limited Duration
# 13                                23.99  5-year Limited Duration
# 14                                25.61  5-year Limited Duration
# 15                                25.34  5-year Limited Duration
# 16                                22.53  5-year Limited Duration
# 17                                25.45  5-year Limited Duration
# 18                                21.95  5-year Limited Duration
# 19                                22.93  5-year Limited Duration
# 20                                22.26  5-year Limited Duration
# 21                                23.77  5-year Limited Duration
# 22                                24.97  5-year Limited Duration
# 23                                26.80  5-year Limited Duration
# 24                                26.78  5-year Limited Duration
# 25                                22.95  5-year Limited Duration
# 26                                23.90  5-year Limited Duration
# 27                                28.20  5-year Limited Duration
# 28                                24.56  5-year Limited Duration
# 29                                22.53  5-year Limited Duration
# 30                                22.36  5-year Limited Duration
# 31                                23.99  5-year Limited Duration
# 32                                19.58  5-year Limited Duration
# 33                                22.43  5-year Limited Duration
# 34                                22.13  5-year Limited Duration
# 35                                23.85  5-year Limited Duration
# 36                                20.98  5-year Limited Duration
# 37                                21.51  5-year Limited Duration
# 38                                21.77  5-year Limited Duration
# 39                                21.67  5-year Limited Duration
# 40                                20.47  5-year Limited Duration
# 41                                19.86  5-year Limited Duration
# 42                                17.56  5-year Limited Duration
# 43                                22.16  5-year Limited Duration
# 44                                19.29  5-year Limited Duration
# 45                                19.63  5-year Limited Duration
# 46                                17.49  5-year Limited Duration
# 47                                20.54  5-year Limited Duration
# 48                                16.39  5-year Limited Duration
# 49                                18.93  5-year Limited Duration
# 50                                22.74  5-year Limited Duration
#
#    Prevalence Count Prevalence of Cancer by state % 5-year relative survival
# 0            179455                      2.01827724                     69.2
# 1             86240                      1.93003662                     61.8
# 2             62806                      1.58918767                     62.4
# 3             52310                      1.75504344                     61.4
# 4             83267                      1.78632129                     63.9
# 5             85304                      1.74097026                     63.0
# 6            119904                       1.7621921                     63.8
# 7             54790                      1.81629949                     63.2
# 8            115135                      1.71465918                     63.3
# 9            107626                      1.75480116                     63.5
# 10            89602                      1.74843337                     64.2
# 11           390876                      2.00412083                     68.6
# 12           171859                      1.62534332                     66.0
# 13  Data Suppressed                 Data Suppressed          Data Suppressed
# 14           380942                      1.32245451                     65.0
# 15            21404                       2.0216331                     69.0
# 16            52542                      1.80389856                     68.8
# 17           217397                       1.8598904                     65.7
# 18  Data Suppressed                 Data Suppressed          Data Suppressed
# 19  Data Suppressed                 Data Suppressed          Data Suppressed
# 20            13123                      1.72242034                     68.9
# 21            34201                      1.77295304                     66.9
# 22  Data Suppressed                 Data Suppressed          Data Suppressed
# 23           423510                      1.98147322                     65.4
# 24            19763                      2.03359345                     66.7
# 25           106764                      1.76511624                     68.7
# 26           189547                      1.81447701                     66.1
# 27            37711                      2.09434813                     61.2
# 28           228852                      1.80257314                     66.2
# 29            29287                      2.18080169                     66.1
# 30  Data Suppressed                 Data Suppressed          Data Suppressed
# 31           259795                      2.02901516                     66.4
# 32             9740                      1.37921269                     65.8
# 33  Data Suppressed                 Data Suppressed          Data Suppressed
# 34           105926                       1.4654881                     64.0
# 35  Data Suppressed                 Data Suppressed          Data Suppressed
# 36           582663                      1.47743255                     67.9
# 37            29190                      2.14960563                     69.8
# 38           112594                      1.93561918                     67.8
# 39             9656                      1.66601965                     68.1
# 40            28386                      1.60321524                     67.0
# 41  Data Suppressed                 Data Suppressed          Data Suppressed
# 42           126751                      1.67429538                     69.4
# 43  Data Suppressed                 Data Suppressed          Data Suppressed
# 44            74143                      1.76538224                     68.9
# 45             9984                      1.35815762                     66.1
# 46            39271                      1.23522144                     73.2
# 47           105566                      1.87692659                     69.9
# 48            83111                      1.45100567                     70.4
# 49            13064                      2.09216814                     68.0
# 50            21369                       2.0046521                     68.2

# %%
cols_to_remove = ['Duration','Prevalence Count',]
Lifestyle_Factors_df.drop(cols_to_remove, axis=1, inplace=True)

# %%
Lifestyle_Factors_df.head()
# Out:
#          State Weekly arobic activity standard meet by state %
# 0   New Jersey                                 Data Suppressed  \
# 1     Kentucky                                            23.7
# 2     Oklahoma                                            31.3
# 3  Mississippi                                            35.5
# 4    Louisiana                                            38.6
#
#   Vegetable Consumption % - less than once per day
# 0                                             17.4  \
# 1                                             17.2
# 2                                             15.9
# 3                                             20.1
# 4                                             20.2
#
#   Fruit Consumption % - less than once per day Binge Drinking % per state
# 0                                         29.5                       13.9  \
# 1                                         40.9                       12.6
# 2                                         40.3                       11.2
# 3                                         42.6                       12.7
# 4                                         40.7                       16.3
#
#    Percentage Affected by Smoking  Percentage Affected by Obesity
# 0                           37.06                           26.28  \
# 1                           50.40                           37.58
# 2                           44.52                           35.63
# 3                           42.85                           39.88
# 4                           43.17                           37.08
#
#    Percentage Affected by No Excercise Prevalence of Cancer by state %
# 0                                28.53                      2.01827724  \
# 1                                32.44                      1.93003662
# 2                                27.20                      1.58918767
# 3                                32.01                      1.75504344
# 4                                30.83                      1.78632129
#
#   5-year relative survival
# 0                     69.2
# 1                     61.8
# 2                     62.4
# 3                     61.4
# 4                     63.9

# %%
Lifestyle_Factors_df.head()
# Out:
#          State Weekly arobic activity standard meet by state %
# 0   New Jersey                                 Data Suppressed  \
# 1     Kentucky                                            23.7
# 2     Oklahoma                                            31.3
# 3  Mississippi                                            35.5
# 4    Louisiana                                            38.6
#
#   Vegetable Consumption % - less than once per day
# 0                                             17.4  \
# 1                                             17.2
# 2                                             15.9
# 3                                             20.1
# 4                                             20.2
#
#   Fruit Consumption % - less than once per day Binge Drinking % per state
# 0                                         29.5                       13.9  \
# 1                                         40.9                       12.6
# 2                                         40.3                       11.2
# 3                                         42.6                       12.7
# 4                                         40.7                       16.3
#
#    Percentage Affected by Smoking  Percentage Affected by Obesity
# 0                           37.06                           26.28  \
# 1                           50.40                           37.58
# 2                           44.52                           35.63
# 3                           42.85                           39.88
# 4                           43.17                           37.08
#
#    Percentage Affected by No Excercise Prevalence of Cancer by state %
# 0                                28.53                      2.01827724  \
# 1                                32.44                      1.93003662
# 2                                27.20                      1.58918767
# 3                                32.01                      1.75504344
# 4                                30.83                      1.78632129
#
#   5-year relative survival
# 0                     69.2
# 1                     61.8
# 2                     62.4
# 3                     61.4
# 4                     63.9

# %%
Lifestyle_Factors_df.to_csv(r'C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\Lifestyle_Factors.csv', index=False)

# %%
from pandasai.llm.openai import OpenAI
llm = OpenAI(
  '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')

# %%
pandas_ai = PandasAI(llm, conversational=False)
pandas_ai.run(Lifestyle_Factors_df, prompt='How many columns does this data frame have?')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[59], line 2
#       1 pandas_ai = PandasAI(llm, conversational=False)
# ----> 2 pandas_ai.run(Lifestyle_Factors_df, prompt='How many columns does this data frame have?')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandasai\__init__.py:126, in PandasAI.run(self, data_frame, prompt, is_conversational_answer, show_code, anonymize_df, use_error_correction_framework)
#     123 if anonymize_df:
#     124     df_head = anonymize_dataframe_head(df_head)
# --> 126 code = self._llm.generate_code(
#     127     self._task_instruction.format(
#     128         today_date=date.today(),
#     129         df_head=df_head,
#     130         num_rows=data_frame.shape[0],
#     131         num_columns=data_frame.shape[1],
#     132         rows_to_display=rows_to_display,
#     133         START_CODE_TAG=START_CODE_TAG,
#     134         END_CODE_TAG=END_CODE_TAG,
#     135     ),
#     136     prompt,
#     137 )
#     138 self._original_instructions = {
#     139     "question": prompt,
#     140     "df_head": df_head,
#    (...)
#     143     "rows_to_display": rows_to_display,
#     144 }
#     145 self.last_code_generated = code
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandasai\llm\base.py:109, in LLM.generate_code(self, instruction, prompt)
#     102 def generate_code(self, instruction: str, prompt: str) -> str:
#     103     """
#     104     Generate the code based on the instruction and the given prompt.
#     105
#     106     Returns:
#     107         str: Code
#     108     """
# --> 109     return self._extract_code(self.call(instruction, prompt, suffix="\n\nCode:\n"))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandasai\llm\openai.py:141, in OpenAI.call(self, instruction, value, suffix)
#     139     response = self.completion(str(instruction) + str(value) + suffix)
#     140 elif self.model in self._supported_chat_models:
# --> 141     response = self.chat_completion(str(instruction) + str(value) + suffix)
#     142 else:
#     143     raise UnsupportedOpenAIModelError("Unsupported model")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandasai\llm\openai.py:118, in OpenAI.chat_completion(self, value)
#     115 if self.stop is not None:
#     116     params["stop"] = [self.stop]
# --> 118 response = openai.ChatCompletion.create(**params)
#     120 return response["choices"][0]["message"]["content"]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#    (...)
#     228         request_timeout=request_timeout,
#     229     )
# --> 230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     616     return (
#     617         self._interpret_response_line(
#     618             line, result.status_code, result.headers, stream=True
#     619         )
#     620         for line in parse_stream(result.iter_lines())
#     621     ), True
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     685 stream_error = stream and "error" in resp.data
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# AuthenticationError: <empty message>

# %%
pandas_ai = PandasAI(llm, conversational=False)
pandas_ai.run(Lifestyle_Factors_df, prompt='What State has the highest 5-year relative survival?')

# %%
pandas_ai = PandasAI(llm, conversational=False)
pandas_ai.run(Lifestyle_Factors_df, prompt='What State has the lowest 5-year relative survival?')

# %%
pandas_ai = PandasAI(llm, conversational=False)
pandas_ai.run(Lifestyle_Factors_df, prompt='What is the mean of 5-year relative survival?')

# %%
pandas_ai = PandasAI(llm, conversational=False)
pandas_ai.run(Lifestyle_Factors_df, prompt='What is the mean of Prevalence of Cancer by state %')

# %% [markdown]
# #LETS USE Stepwise multiple linear regression is a method of fitting a regression model that involves automatically selecting the best subset of predictors. It begins with an initial model and then compares the explanatory power of incrementally larger and smaller models.

# %%
# !pip install statsmodels

# %%
import numpy as np
import statsmodels.api as sm

# %%
# Removing non-numeric columns (in your case 'State')
Lifestyle_Factors_df_DROPPED = Lifestyle_Factors_df.select_dtypes(include=[np.number])

# %%
# Filling NaN values with the mean of the respective column
Lifestyle_Factors_df_DROPPED = Lifestyle_Factors_df_DROPPED.fillna(Lifestyle_Factors_df_DROPPED.mean())

# %%
# Defining the dependent variable (y) and independent variables (X)
X = Lifestyle_Factors_df_DROPPED.drop('Prevalence of Cancer by state %', axis=1)
y = Lifestyle_Factors_df_DROPPED['Prevalence of Cancer by state %']

# %%
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

result = stepwise_selection(X, y)

print('resulting features:')
print(result)

# %%
Cancer_df = pd.read_csv(r'C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\Lifestyle_Factors_NOnull.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# List of columns that you want to consider for correlation
columns_to_consider = ['Prevalence of Cancer by state %', 'Weekly arobic activity standard meet by state %', 
                       'Vegetable Consumption % - less than once per day', 
                       'Fruit Consumption % - less than once per day', 
                       'Binge Drinking % per state', 
                       'Percentage Affected by Smoking', 
                       'Percentage Affected by Obesity', 
                       'Percentage Affected by No Excercise', 
                       '5-year relative survival']

# %%
# Get correlation of only these columns
correlation = Cancer_df[columns_to_consider].corr()

# %%
# Use seaborn to create a heatmap of the correlations
plt.figure(figsize=(10,8))  # Adjust figure size as needed
sns.heatmap(correlation, annot=True, cmap="coolwarm")

plt.show()

# %%
Cancer_df = pd.read_csv(r'C:\Users\MrMan\Documents\GitHub\CD-DS-Final-Project\Data\Lifestyle_Factors_NOnull.csv')

# %%
Cancer_df = df.drop('State', axis=1)

# %%
# Calculate the correlation
correlation = Cancer_df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 2
#       1 # Calculate the correlation
# ----> 2 correlation = Cancer_df.corr()
#
# File C:\Python3\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Python3\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\Python3\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File C:\Python3\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'New Jersey'

# %%
# Get correlations of 'Prevalence of Cancer by state %' with all other columns
cancer_correlation = correlation['Prevalence of Cancer by state %']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python3\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Prevalence of Cancer by state %'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 2
#       1 # Get correlations of 'Prevalence of Cancer by state %' with all other columns
# ----> 2 cancer_correlation = correlation['Prevalence of Cancer by state %']
#
# File C:\Python3\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File C:\Python3\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Prevalence of Cancer by state %'

# %%
# Drop 'Prevalence of Cancer by state %' as we don't want to include the correlation of the variable with itself
cancer_correlation = cancer_correlation.drop('Prevalence of Cancer by state %'.'5-year relative survival')
# Out:
#   Cell In[87], line 2
#     cancer_correlation = cancer_correlation.drop('Prevalence of Cancer by state %'.'5-year relative survival')
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
# Create bar plot
cancer_correlation.plot(kind='bar', figsize=(10,6))
plt.title('Correlation with Prevalence of Cancer by State %')
plt.ylabel('Correlation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 # Create bar plot
# ----> 2 cancer_correlation.plot(kind='bar', figsize=(10,6))
#       3 plt.title('Correlation with Prevalence of Cancer by State %')
#       4 plt.ylabel('Correlation')
#
# NameError: name 'cancer_correlation' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming df is your DataFrame and it has been sorted based on 'Prevalence of Cancer by state %'

# %%
N = 50  # Choose the number of states you want to display
ind = np.arange(N)
width = 0.35

fig, ax = plt.subplots()

rects1 = ax.bar(ind - width/2, Cancer_df['Percentage Affected by Smoking'][:N], width, label='Smoking')
rects2 = ax.bar(ind + width/2, Cancer_df['Percentage Affected by Obesity'][:N], width, label='Obesity')

ax.set_xlabel('States')
ax.set_ylabel('Percentage')
ax.set_title('Impact of Smoking and Obesity on Cancer Prevalence by State')
ax.set_xticks(ind)
ax.set_xticklabels(df['State'][:N], rotation='vertical')
ax.legend()

fig.tight_layout()

plt.show()
